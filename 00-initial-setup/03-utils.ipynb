# %%
# Define Warrior schemas
wr_bronze_schema = 'warrior_bronze'
wr_silver_schema = 'warrior_silver'
wr_gold_schema = 'warrior_gold'

# %%
# Define Sports Direct schema
sd_gold_schema = 'sportsdirect_gold'
